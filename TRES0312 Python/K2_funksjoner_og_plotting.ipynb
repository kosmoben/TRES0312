# %% [markdown]
# # Eksempel 2 – Funksjoner og plotting
# **TRES0312 Fysikk — Kapittel 1: Matematiske verktøy**
#
# Vi plotter posisjon og fart som funksjon av tid for et legeme med konstant akselerasjon:
# $$x(t) = x_0 + v_0 t + \frac{1}{2}at^2, \qquad v(t) = v_0 + at$$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametre
a  = 2.0    # akselerasjon [m/s^2]
v0 = 0.0    # startfart [m/s]
x0 = 0.0    # startposisjon [m]

# Tid fra 0 til 5 sekunder
t = np.linspace(0, 5, 200)

# Bevegelsesligninger
x = x0 + v0*t + 0.5*a*t**2   # posisjon
v = v0 + a*t                  # fart

# To grafer side om side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

ax1.plot(t, x, color='royalblue', linewidth=2)
ax1.set_xlabel('Tid [s]')
ax1.set_ylabel('Posisjon [m]')
ax1.set_title('Posisjon vs. tid')
ax1.grid(True, alpha=0.3)

ax2.plot(t, v, color='tomato', linewidth=2)
ax2.set_xlabel('Tid [s]')
ax2.set_ylabel('Fart [m/s]')
ax2.set_title('Fart vs. tid')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Prøv selv
# - Endre `v0 = 3.0` og kjør på nytt. Hva skjer med grafene?
# - Prøv negativ akselerasjon, f.eks. `a = -9.81` (fritt fall nedover).
